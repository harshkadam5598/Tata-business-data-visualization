# %%
import pandas as pd
import numpy as np

# %%
# Load raw dataset
df = pd.read_csv("/content/global_superstore2.csv", encoding="latin1")

# Quick inspection
df.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878  05-02-2013  07-02-2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320  05-11-2013  06-11-2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# 0   TEC-AC-10003033  Technology  Accessories
# 1   FUR-CH-10003950   Furniture       Chairs
# 2   TEC-PH-10004664  Technology       Phones
# 3   TEC-PH-10004583  Technology       Phones
# 4  TEC-SHA-10000501  Technology      Copiers
#
#                                         Product Name     Sales Quantity  \
# 0  Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1          Novimex Executive Leather Armchair, Black  3709.395        9
# 2                  Nokia Smart Phone, with Caller ID  5175.171        9
# 3                     Motorola Smart Phone, Cordless  2892.510        5
# 4                     Sharp Wireless Fax, High-Speed  2832.960        8
#
#   Discount    Profit  Shipping Cost  Order Priority
# 0      0.0  762.1845         933.57        Critical
# 1      0.1 -288.7650         923.63        Critical
# 2      0.1  919.9710         915.49          Medium
# 3      0.1  -96.5400         910.16          Medium
# 4      0.0  311.5200         903.04        Critical
#
# [5 rows x 24 columns]

# %%
# Dataset shape
print("Rows, Columns:", df.shape)

# Column names
df.columns
# Out:
# Rows, Columns: (51290, 24)
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.replace(" ", "_")
    .str.replace("-", "_")
)

# %%
df.columns
# Out:
# Index(['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'City', 'State', 'Country',
#        'Postal_Code', 'Market', 'Region', 'Product_ID', 'Category',
#        'Sub_Category', 'Product_Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping_Cost', 'Order_Priority'],
#       dtype='object')

# %%
# Missing values
df.isnull().sum().sort_values(ascending=False)
# Out:
# Postal_Code       41296
# Row_ID                0
# Order_Date            0
# Order_ID              0
# Ship_Mode             0
# Customer_ID           0
# Customer_Name         0
# Ship_Date             0
# Segment               0
# City                  0
# State                 0
# Country               0
# Market                0
# Region                0
# Product_ID            0
# Category              0
# Sub_Category          0
# Product_Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping_Cost         0
# Order_Priority        0
# dtype: int64

# %%
# Duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Convert date columns
df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Ship_Date'] = pd.to_datetime(df['Ship_Date'])

# Remove duplicates
df = df.drop_duplicates()

# Drop rows with critical missing values
df = df.dropna(subset=['Sales', 'Profit', 'Order_Date'])
# Out:
# /tmp/ipython-input-256044613.py:2: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Order_Date'] = pd.to_datetime(df['Order_Date'])
# /tmp/ipython-input-256044613.py:3: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Ship_Date'] = pd.to_datetime(df['Ship_Date'])

# %% [markdown]
# **Time-Based Feature Engineering**

# %%
df['Order_Year'] = df['Order_Date'].dt.year
df['Order_Month'] = df['Order_Date'].dt.month
df['Order_Month_Name'] = df['Order_Date'].dt.month_name()
df['Order_Quarter'] = df['Order_Date'].dt.to_period('Q').astype(str)

# %% [markdown]
# **Profitability Metrics**

# %%
# Profit margin %
df['Profit_Margin_Pct'] = (df['Profit'] / df['Sales']) * 100

# Profit flag
df['Profit_Flag'] = np.where(df['Profit'] > 0, 'Profitable', 'Loss')

# %% [markdown]
# **Order Value Segmentation (Business Intelligence)**
#
# This enables 80/20 analysis and high-value customer insights.

# %%
# Quartile thresholds
q1 = df['Sales'].quantile(0.25)
q3 = df['Sales'].quantile(0.75)

def order_segment(sales):
    if sales >= q3:
        return 'High Value'
    elif sales <= q1:
        return 'Low Value'
    else:
        return 'Medium Value'

df['Order_Value_Segment'] = df['Sales'].apply(order_segment)

# %% [markdown]
# **Operational Metrics (Hidden Differentiator)**

# %%
# Shipping delay in days
df['Shipping_Delay_Days'] = (df['Ship_Date'] - df['Order_Date']).dt.days

# Delay flag
df['Delayed_Shipment'] = np.where(df['Shipping_Delay_Days'] > 5, 'Yes', 'No')

# %% [markdown]
# **Final Sanity Checks**

# %%
df.describe(include='all').transpose()
# Out:
#                        count unique              top   freq  \
# Row_ID               51290.0    NaN              NaN    NaN
# Order_ID               51290  25035   CA-2014-100111     14
# Order_Date             51290    NaN              NaN    NaN
# Ship_Date              51290    NaN              NaN    NaN
# Ship_Mode              51290      4   Standard Class  30775
# Customer_ID            51290   1590         PO-18850     97
# Customer_Name          51290    795  Muhammed Yedwab    108
# Segment                51290      3         Consumer  26518
# City                   51290   3636    New York City    915
# State                  51290   1094       California   2001
# Country                51290    147    United States   9994
# Postal_Code           9994.0    NaN              NaN    NaN
# Market                 51290      7             APAC  11002
# Region                 51290     13          Central  11117
# Product_ID             51290  10292  OFF-AR-10003651     35
# Category               51290      3  Office Supplies  31273
# Sub_Category           51290     17          Binders   6152
# Product_Name           51290   3788          Staples    227
# Sales                51290.0    NaN              NaN    NaN
# Quantity             51290.0    NaN              NaN    NaN
# Discount             51290.0    NaN              NaN    NaN
# Profit               51290.0    NaN              NaN    NaN
# Shipping_Cost        51290.0    NaN              NaN    NaN
# Order_Priority         51290      4           Medium  29433
# Order_Year           51290.0    NaN              NaN    NaN
# Order_Month          51290.0    NaN              NaN    NaN
# Order_Month_Name       51290     12         November   6342
# Order_Quarter          51290     16           2014Q4   5926
# Profit_Margin_Pct    51290.0    NaN              NaN    NaN
# Profit_Flag            51290      2       Profitable  38078
# Order_Value_Segment    51290      3     Medium Value  25644
# Shipping_Delay_Days  51290.0    NaN              NaN    NaN
# Delayed_Shipment       51290      2               No  41978
#
#                                               mean                  min  \
# Row_ID                                     25645.5                  1.0
# Order_ID                                       NaN                  NaN
# Order_Date           2013-05-11 21:26:49.155781120  2011-01-01 00:00:00
# Ship_Date            2013-05-15 20:42:42.745174528  2011-01-03 00:00:00
# Ship_Mode                                      NaN                  NaN
# Customer_ID                                    NaN                  NaN
# Customer_Name                                  NaN                  NaN
# Segment                                        NaN                  NaN
# City                                           NaN                  NaN
# State                                          NaN                  NaN
# Country                                        NaN                  NaN
# Postal_Code                           55190.379428               1040.0
# Market                                         NaN                  NaN
# Region                                         NaN                  NaN
# Product_ID                                     NaN                  NaN
# Category                                       NaN                  NaN
# Sub_Category                                   NaN                  NaN
# Product_Name                                   NaN                  NaN
# Sales                                   246.490581                0.444
# Quantity                                  3.476545                  1.0
# Discount                                  0.142908                  0.0
# Profit                                   28.610982            -6599.978
# Shipping_Cost                            26.375915                  0.0
# Order_Priority                                 NaN                  NaN
# Order_Year                             2012.777208               2011.0
# Order_Month                               7.522636                  1.0
# Order_Month_Name                               NaN                  NaN
# Order_Quarter                                  NaN                  NaN
# Profit_Margin_Pct                          4.74296          -473.354185
# Profit_Flag                                    NaN                  NaN
# Order_Value_Segment                            NaN                  NaN
# Shipping_Delay_Days                        3.96937                  0.0
# Delayed_Shipment                               NaN                  NaN
#
#                                      25%                  50%  \
# Row_ID                          12823.25              25645.5
# Order_ID                             NaN                  NaN
# Order_Date           2012-06-19 00:00:00  2013-07-08 00:00:00
# Ship_Date            2012-06-23 00:00:00  2013-07-12 00:00:00
# Ship_Mode                            NaN                  NaN
# Customer_ID                          NaN                  NaN
# Customer_Name                        NaN                  NaN
# Segment                              NaN                  NaN
# City                                 NaN                  NaN
# State                                NaN                  NaN
# Country                              NaN                  NaN
# Postal_Code                      23223.0              56430.5
# Market                               NaN                  NaN
# Region                               NaN                  NaN
# Product_ID                           NaN                  NaN
# Category                             NaN                  NaN
# Sub_Category                         NaN                  NaN
# Product_Name                         NaN                  NaN
# Sales                          30.758625               85.053
# Quantity                             2.0                  3.0
# Discount                             0.0                  0.0
# Profit                               0.0                 9.24
# Shipping_Cost                       2.61                 7.79
# Order_Priority                       NaN                  NaN
# Order_Year                        2012.0               2013.0
# Order_Month                          5.0                  8.0
# Order_Month_Name                     NaN                  NaN
# Order_Quarter                        NaN                  NaN
# Profit_Margin_Pct                    0.0            16.917784
# Profit_Flag                          NaN                  NaN
# Order_Value_Segment                  NaN                  NaN
# Shipping_Delay_Days                  3.0                  4.0
# Delayed_Shipment                     NaN                  NaN
#
#                                      75%                  max          std
# Row_ID                          38467.75              51290.0  14806.29199
# Order_ID                             NaN                  NaN          NaN
# Order_Date           2014-05-22 00:00:00  2014-12-31 00:00:00          NaN
# Ship_Date            2014-05-26 00:00:00  2015-01-07 00:00:00          NaN
# Ship_Mode                            NaN                  NaN          NaN
# Customer_ID                          NaN                  NaN          NaN
# Customer_Name                        NaN                  NaN          NaN
# Segment                              NaN                  NaN          NaN
# City                                 NaN                  NaN          NaN
# State                                NaN                  NaN          NaN
# Country                              NaN                  NaN          NaN
# Postal_Code                      90008.0              99301.0  32063.69335
# Market                               NaN                  NaN          NaN
# Region                               NaN                  NaN          NaN
# Product_ID                           NaN                  NaN          NaN
# Category                             NaN                  NaN          NaN
# Sub_Category                         NaN                  NaN          NaN
# Product_Name                         NaN                  NaN          NaN
# Sales                           251.0532             22638.48   487.565361
# Quantity                             5.0                 14.0     2.278766
# Discount                             0.2                 0.85      0.21228
# Profit                             36.81             8399.976   174.340972
# Shipping_Cost                      24.45               933.57    57.296804
# Order_Priority                       NaN                  NaN          NaN
# Order_Year                        2014.0               2014.0     1.098931
# Order_Month                         10.0                 12.0     3.300056
# Order_Month_Name                     NaN                  NaN          NaN
# Order_Quarter                        NaN                  NaN          NaN
# Profit_Margin_Pct              33.313913                 50.0    46.566708
# Profit_Flag                          NaN                  NaN          NaN
# Order_Value_Segment                  NaN                  NaN          NaN
# Shipping_Delay_Days                  5.0                  7.0     1.729437
# Delayed_Shipment                     NaN                  NaN          NaN

# %%
df.head()
# Out:
#    Row_ID         Order_ID Order_Date  Ship_Date     Ship_Mode Customer_ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer_Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#   Order_Priority  Order_Year Order_Month Order_Month_Name Order_Quarter  \
# 0       Critical        2012           7             July        2012Q3
# 1       Critical        2013           2         February        2013Q1
# 2         Medium        2013          10          October        2013Q4
# 3         Medium        2013           1          January        2013Q1
# 4       Critical        2013          11         November        2013Q4
#
#   Profit_Margin_Pct Profit_Flag Order_Value_Segment  Shipping_Delay_Days  \
# 0         33.000000  Profitable          High Value                    0
# 1         -7.784693        Loss          High Value                    2
# 2         17.776630  Profitable          High Value                    1
# 3         -3.337586        Loss          High Value                    2
# 4         10.996272  Profitable          High Value                    1
#
#    Delayed_Shipment
# 0                No
# 1                No
# 2                No
# 3                No
# 4                No
#
# [5 rows x 33 columns]

# %% [markdown]
#  **Export BI-READY DATASET**

# %%
df.to_csv("/content/cleaned_global_superstore2.csv", index=False)

print("Cleaned dataset exported successfully.")
# Out:
# Cleaned dataset exported successfully.
